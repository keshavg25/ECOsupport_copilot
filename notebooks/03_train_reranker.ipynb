# %% [markdown]
# # 03 — Train Reranker (Cross-encoder)
#
# Trains `cross-encoder/ms-marco-MiniLM-L-6-v2` on (query, passage, label).
# Output: `models/reranker/`
#
# This step hits the next ⏸️ training checkpoint in the project.

# %%
import os
import subprocess

ROOT = os.path.abspath(os.path.join(os.getcwd(), '..')) if os.path.basename(os.getcwd()) == 'notebooks' else os.path.abspath(os.getcwd())
cmd = [
, os.path.join(ROOT, 
, 
, 
),
, os.path.join(ROOT, 
, 
, 
),
, os.path.join(ROOT, 
, 
),
, 
2
,
, 
16
,
, 
0.00002
,
