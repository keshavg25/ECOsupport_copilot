# %% [markdown]
# # 02 — Train Retriever (Bi-encoder)
#
# Trains sentence-transformers bi-encoder using MultipleNegativesRankingLoss.
# Output: `models/retriever/`

# %%
import os
import subprocess

ROOT = os.path.abspath(os.path.join(os.getcwd(), '..')) if os.path.basename(os.getcwd()) == 'notebooks' else os.path.abspath(os.getcwd())
cmd = [
, os.path.join(ROOT, 
, 
, 
),
, os.path.join(ROOT, 
, 
, 
),
, os.path.join(ROOT, 
, 
),
, 
3
,
, 
32
,
, 
0.00002
,
